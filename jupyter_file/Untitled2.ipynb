# %%
import pandas as pd

df_20170810 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170810.csv')
df_20170811 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170811.csv')
df_20170812 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170812.csv')
df_20170813 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170813.csv')
df_20170814 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170814.csv')
df_20170815 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170815.csv')
df_20170816 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170816.csv')
df_20170817 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170817.csv')
df_20170818 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170818.csv')
df_20170819 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170819.csv')
df_20170820 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170820.csv')
df_20170821 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170821.csv')
df_20170822 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170822.csv')
df_20170823 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170823.csv')
df_20170824 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170824.csv')
df_20170825 = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/SAP_MEETINGJMT_20170825.csv')

# %%
col_list = ['ROWKEY', 'CONFID', 'GID', 'UID_', 'USERTYPE', 'PLATFORM', 'STARTJOINTIME',
              'JOINEDTIME', 'CUSTOMERPCIP', 'CUSTOMERGWIP', 'REFNUM6', 'USEROS', 'USERBROWSER', 'DOWNLOADMETHOD', 
              'SERVICETYPE', 'SITEID', 'USERJMT', 'SITEVERSION', 'JOINSUCCESS']

df_20170810.columns = col_list
df_20170811.columns = col_list
df_20170812.columns = col_list
df_20170813.columns = col_list
df_20170814.columns = col_list
df_20170815.columns = col_list
df_20170816.columns = col_list
df_20170817.columns = col_list
df_20170818.columns = col_list
df_20170819.columns = col_list
df_20170820.columns = col_list
df_20170821.columns = col_list
df_20170822.columns = col_list
df_20170823.columns = col_list
df_20170824.columns = col_list
df_20170825.columns = col_list

def substr_map(value):
    return value[1:len(value)-1]

for col in col_list:
    df_20170810[col] = df_20170810[col].map(substr_map)
    df_20170811[col] = df_20170811[col].map(substr_map)
    df_20170812[col] = df_20170812[col].map(substr_map)
    df_20170813[col] = df_20170813[col].map(substr_map)
    df_20170814[col] = df_20170814[col].map(substr_map)
    df_20170815[col] = df_20170815[col].map(substr_map)
    df_20170816[col] = df_20170816[col].map(substr_map)
    df_20170817[col] = df_20170817[col].map(substr_map)
    df_20170818[col] = df_20170818[col].map(substr_map)
    df_20170819[col] = df_20170819[col].map(substr_map)
    df_20170820[col] = df_20170820[col].map(substr_map)
    df_20170821[col] = df_20170821[col].map(substr_map)
    df_20170822[col] = df_20170822[col].map(substr_map)
    df_20170823[col] = df_20170823[col].map(substr_map)
    df_20170824[col] = df_20170824[col].map(substr_map)
    df_20170825[col] = df_20170825[col].map(substr_map)
    
df_20170810["USERJMT"] = df_20170810["USERJMT"].astype(int)
df_20170811["USERJMT"] = df_20170811["USERJMT"].astype(int)
df_20170812["USERJMT"] = df_20170812["USERJMT"].astype(int)
df_20170813["USERJMT"] = df_20170813["USERJMT"].astype(int)
df_20170814["USERJMT"] = df_20170814["USERJMT"].astype(int)
df_20170815["USERJMT"] = df_20170815["USERJMT"].astype(int)
df_20170816["USERJMT"] = df_20170816["USERJMT"].astype(int)
df_20170817["USERJMT"] = df_20170817["USERJMT"].astype(int)
df_20170818["USERJMT"] = df_20170818["USERJMT"].astype(int)
df_20170819["USERJMT"] = df_20170819["USERJMT"].astype(int)
df_20170820["USERJMT"] = df_20170820["USERJMT"].astype(int)
df_20170821["USERJMT"] = df_20170821["USERJMT"].astype(int)
df_20170822["USERJMT"] = df_20170822["USERJMT"].astype(int)
df_20170823["USERJMT"] = df_20170823["USERJMT"].astype(int)
df_20170824["USERJMT"] = df_20170824["USERJMT"].astype(int)
df_20170825["USERJMT"] = df_20170825["USERJMT"].astype(int)

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties  
myfont = FontProperties(fname='/Library/Fonts/Songti.ttc')

plt.figure(figsize=(10, 4))
count_series = df_20170810.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-10 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170811.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-11 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170812.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-12 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170813.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-13 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170814.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-14 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170815.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-15 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170816.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-16 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170817.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-17 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170818.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-18 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170819.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-19 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170820.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-20 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170821.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-21 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170822.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-22 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170823.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-23 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170824.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-24 JMT Distributed')
plt.legend()
plt.show()

plt.figure(figsize=(10, 4))
count_series = df_20170825.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='8-25 JMT Distributed')
plt.legend()
plt.show()
pd.set_option('display.max_rows',None)
# print count_series[0:100]

# %%
# 把所有的dataframe 基于行进行拼接
df = pd.concat([df_20170810,df_20170811,df_20170812,df_20170813,df_20170814, df_20170815, df_20170816, df_20170817, df_20170818,df_20170819, df_20170820, df_20170821, df_20170822, df_20170823, df_20170824, df_20170825])
df = df.reset_index()
df.shape
# Out:
# (1555862, 20)

# %%
plt.figure(figsize=(10, 4))
count_series = df.USERJMT.value_counts().sort_index()[0:100]
count_series.plot(label='08 JMT Distributed')
plt.legend()
plt.show()

print count_series[0:100]
# Out:
# 0      18034
# 1      56071
# 2     139347
# 3     297988
# 4     240115
# 5     146411
# 6     112845
# 7      84268
# 8      58600
# 9      44217
# 10     34109
# 11     27694
# 12     23407
# 13     19392
# 14     16283
# 15     13870
# 16     12252
# 17     10808
# 18      9887
# 19      9228
# 20      8337
# 21      7690
# 22      7099
# 23      6659
# 24      6081
# 25      5496
# 26      5000
# 27      4567
# 28      4320
# 29      4242
# 30      3920
# 31      3774
# 32      3778
# 33      3694
# 34      3578
# 35      3584
# 36      3496
# 37      3563
# 38      3254
# 39      3427
# 40      3454
# 41      3228
# 42      3172
# 43      2974
# 44      3016
# 45      2844
# 46      2667
# 47      2487
# 48      2382
# 49      2276
# 50      2025
# 51      2028
# 52      1921
# 53      1792
# 54      1743
# 55      1660
# 56      1539
# 57      1442
# 58      1456
# 59      1345
# 60      1300
# 61      1227
# 62      1148
# 63      1080
# 64      1090
# 65       959
# ...

# %%
# 生成新字段ID，用GID或UID的值表示
df.insert(0,'ID',df.GID+df.UID_)

# 生成新字段register，0表示为注册用户，1表示为没注册用户。uid对应0，gid对应1
bool_to_num =  {False:0, True: 1}
register = (df['GID']!='0').map(bool_to_num)
df.insert(6,'REGISTER',register)

# %%
# 并且原来的删除GID和UID两个字段
del df['GID']
del df['UID_']
del df['JOINSUCCESS']

# %%
# 对于 USEROS 和 USERBROWSER 进行分析处理
# 生成 PC、moblie特征
from collections import OrderedDict 

o_dict = OrderedDict()
o_dict['Phone'] = 'Moblie'
o_dict['Android'] = 'Moblie'
o_dict['iOS'] = 'Moblie'
o_dict['Other'] = 'Other'
o_dict['Windows'] = 'PC'
o_dict['Linux'] = 'PC'
o_dict['intel mac os x'] = 'PC'
o_dict['Chrome OS'] = 'PC'

def category_unify_by_char(category_field):
    index_field_dict = {}
    for index, field in df[category_field].iteritems():
        for useros, flag in o_dict.items():
            if useros in field:
                index_field_dict[index] = flag
                break
    return pd.Series(index_field_dict)  

MACHINE_TYPE = category_unify_by_char('USEROS')
df['MACHINE_TYPE'] = MACHINE_TYPE


def category_unify(category_field, threshold):
    field_count_dict = df[category_field].value_counts()<threshold
    index_field_dict ={}
    for index, field in df[category_field].iteritems():
        index_field_dict[index] = field_count_dict[field]
    return pd.Series(index_field_dict) 

df.loc[category_unify('USEROS', 1000), 'USEROS' ] = "Other"
df.loc[category_unify('USERBROWSER', 1000), 'USERBROWSER' ] = "Other"

# %%
# print df.USEROS.value_counts()
# print df.USERBROWSER.value_counts()
# Out:
# Windows 7               436729
# Windows 10              365728
# intel mac os x 10.12    244378
# Windows 8.1             134097
# intel mac os x 10.11    114906
# WbxTPAgent               74471
# iOS                      61731
# intel mac os x 10.6      49506
# intel mac os x 10.10     25642
# Other                    19368
# Android 9.14              7775
# intel mac os x 10.7       7384
# Android 9.13              6992
# Windows Vista             3988
# Windows 8                 1687
# intel mac os x 10.9       1480
# Name: USEROS, dtype: int64
# Chrome 60                           366665
# Other                               290264
# IE 11.0                             238498
# Firefox 54                          180903
# Safari 10                           122407
# wbxtpgw                              74471
# Chrome 59                            68626
# Firefox 55                           56566
# Chrome 10                            49506
# ...

# %%
df.to_csv('../data/SAP_MEETINGJMT_20170810-20170825/all_jmt.csv',index=False)

# %% [markdown]
# ##  对100w的数据进行分析(表现比较好，JMT小于6的数据)

# %%
import pandas as pd
df = pd.read_csv('../data/SAP_MEETINGJMT_20170810-20170825/all_jmt.csv')

df_all6 = df[df.USERJMT<=6]
print df_all6.columns.values
print df_all6.shape
# df_sample.head()
# Out:
# ['ID' 'index' 'ROWKEY' 'CONFID' 'REGISTER' 'USERTYPE' 'PLATFORM'
#  'STARTJOINTIME' 'JOINEDTIME' 'CUSTOMERPCIP' 'CUSTOMERGWIP' 'REFNUM6'
#  'USEROS' 'USERBROWSER' 'DOWNLOADMETHOD' 'SERVICETYPE' 'SITEID' 'USERJMT'
#  'SITEVERSION' 'MACHINE_TYPE']
# (1010811, 20)

# %%
print df_all6.USEROS.value_counts()
print df_all6.USERBROWSER.value_counts()
# Out:
# Windows 10              236106
# Windows 7               217315
# intel mac os x 10.12    191264
# intel mac os x 10.11     90419
# WbxTPAgent               72320
# iOS                      56063
# Windows 8.1              54891
# intel mac os x 10.6      41191
# intel mac os x 10.10     19371
# Other                    10262
# Android 9.14              6826
# Android 9.13              6088
# intel mac os x 10.7       5517
# Windows Vista             1529
# intel mac os x 10.9       1069
# Windows 8                  580
# Name: USEROS, dtype: int64
# Chrome 60                           234464
# IE 11.0                             151433
# Other                               144849
# Firefox 54                          120736
# Safari 10                            98060
# wbxtpgw                              72320
# Chrome 59                            45150
# Chrome 10                            41191
# Firefox 55                           40662
# ...

# %% [markdown]
# ## 全部数据分析

# %%
# USERJMT 字段进行映射为[0,2]
def jmt_map(x):
    if 0 <= x <= 8:
        return 1
#     elif 6 <= x <= 20:
#         return 1
    elif 8 < x :
        return 0

df['USERJMT_DIS'] = df.USERJMT.map(jmt_map)
df.USERJMT_DIS.value_counts()
# Out:
# 1    1153679
# 0     402183
# Name: USERJMT_DIS, dtype: int64

# %%
# 类别特征进行二值化编码
# dummies_HOUR = pd.get_dummies(df['HOUR'], prefix= 'HOUR')
dummies_USERTYPE = pd.get_dummies(df['USERTYPE'], prefix= 'USERTYPE')
dummies_PLATFORM = pd.get_dummies(df['PLATFORM'], prefix= 'PLATFORM')
# dummies_REGISTER = pd.get_dummies(df['REGISTER'], prefix= 'REGISTER')
dummies_REFNUM6 = pd.get_dummies(df['REFNUM6'], prefix= 'REFNUM6')
dummies_USEROS = pd.get_dummies(df['USEROS'], prefix= 'USEROS')
dummies_USERBROWSER = pd.get_dummies(df['USERBROWSER'], prefix= 'USERBROWSER')
dummies_DOWNLOADMETHOD = pd.get_dummies(df['DOWNLOADMETHOD'], prefix= 'DOWNLOADMETHOD')
dummies_SERVICETYPE = pd.get_dummies(df['SERVICETYPE'], prefix= 'SERVICETYPE')
# dummies_COUNTRY = pd.get_dummies(df['COUNTRY'], prefix= 'COUNTRY')
# dummies_REGION = pd.get_dummies(df['REGION'], prefix= 'REGION')
# dummies_CITY = pd.get_dummies(df['CITY'], prefix= 'CITY')
dummies_MACHINE_TYPE = pd.get_dummies(df['MACHINE_TYPE'], prefix= 'MACHINE_TYPE')


# jmt_feature = pd.concat([dummies_HOUR, dummies_USERTYPE, dummies_PLATFORM,df['REGISTER'],dummies_REFNUM6,dummies_USEROS,dummies_USERBROWSER,dummies_DOWNLOADMETHOD,dummies_SERVICETYPE,dummies_COUNTRY,dummies_REGION,dummies_CITY,dummies_MACHINE_TYPE], axis=1)
jmt_feature = pd.concat([dummies_USERTYPE, dummies_PLATFORM,df['REGISTER'],dummies_REFNUM6,dummies_USEROS,dummies_USERBROWSER,dummies_DOWNLOADMETHOD,dummies_SERVICETYPE,dummies_MACHINE_TYPE], axis=1)
jmt_target = df.loc[:,['USERJMT_DIS']]

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
print jmt_feature.shape
# Out:
# (1555862, 90)

# %%
# 把数据集随机拆为训练集和测试集

from sklearn.cross_validation import train_test_split
jmt_sample_train, jmt_sample_test, jmt_target_train, jmt_target_test = train_test_split(jmt_feature, jmt_target, test_size=0.25, random_state=1)

# %%
# 转化为numpy数据格式，输入决策树训练. entropy 为信息增益
from sklearn.tree import DecisionTreeClassifier

jmt_DTC=DecisionTreeClassifier(criterion='gini',max_depth=7)
jmt_DTC=jmt_DTC.fit(jmt_sample_train, jmt_target_train)
print jmt_sample_train.columns.values
# Out:
# ['USERTYPE_New' 'USERTYPE_Return' 'USERTYPE_Update' 'PLATFORM_0'
#  'PLATFORM_1' 'PLATFORM_4' 'PLATFORM_5' 'PLATFORM_7' 'PLATFORM_10'
#  'PLATFORM_11' 'PLATFORM_12' 'PLATFORM_13' 'PLATFORM_15' 'REGISTER'
#  'REFNUM6_0' 'REFNUM6_2' 'REFNUM6_5' 'REFNUM6_8' 'REFNUM6_15' 'REFNUM6_16'
#  'REFNUM6_17' 'REFNUM6_19' 'REFNUM6_22' 'REFNUM6_28' 'REFNUM6_41'
#  'REFNUM6_43' 'REFNUM6_45' 'REFNUM6_51' 'USEROS_Android 9.13'
#  'USEROS_Android 9.14' 'USEROS_Other' 'USEROS_WbxTPAgent'
#  'USEROS_Windows 10' 'USEROS_Windows 7' 'USEROS_Windows 8'
#  'USEROS_Windows 8.1' 'USEROS_Windows Vista' 'USEROS_iOS'
#  'USEROS_intel mac os x 10.10' 'USEROS_intel mac os x 10.11'
#  'USEROS_intel mac os x 10.12' 'USEROS_intel mac os x 10.6'
#  'USEROS_intel mac os x 10.7' 'USEROS_intel mac os x 10.9'
#  'USERBROWSER_Android 9.13.0.19130148.19130148'
#  'USERBROWSER_Android 9.14.0.19140171.19140171' 'USERBROWSER_Chrome 10'
#  'USERBROWSER_Chrome 34' 'USERBROWSER_Chrome 46' 'USERBROWSER_Chrome 51'
# ...

# %%
# 结果展示
from IPython.display import Image  
from sklearn.externals.six import StringIO
import pydotplus
from sklearn import tree

dot_data = StringIO() 
tree.export_graphviz(jmt_DTC, out_file=dot_data, 
  feature_names = ['USERTYPE_New','USERTYPE_Return','USERTYPE_Update','PLATFORM_0',
 'PLATFORM_1','PLATFORM_4','PLATFORM_5','PLATFORM_7','PLATFORM_10',
 'PLATFORM_11','PLATFORM_12','PLATFORM_13','PLATFORM_15','REGISTER',
 'REFNUM6_0','REFNUM6_2','REFNUM6_5','REFNUM6_8','REFNUM6_15','REFNUM6_16',
 'REFNUM6_17','REFNUM6_19','REFNUM6_22','REFNUM6_28','REFNUM6_41',
 'REFNUM6_43','REFNUM6_45','REFNUM6_51','USEROS_Android 9.13',
 'USEROS_Android 9.14','USEROS_Other','USEROS_WbxTPAgent',
 'USEROS_Windows 10','USEROS_Windows 7','USEROS_Windows 8',
 'USEROS_Windows 8.1','USEROS_Windows Vista','USEROS_iOS',
 'USEROS_intel mac os x 10.10','USEROS_intel mac os x 10.11',
 'USEROS_intel mac os x 10.12','USEROS_intel mac os x 10.6',
 'USEROS_intel mac os x 10.7','USEROS_intel mac os x 10.9',
 'USERBROWSER_Android 9.13.0.19130148.19130148',
 'USERBROWSER_Android 9.14.0.19140171.19140171','USERBROWSER_Chrome 10',
 'USERBROWSER_Chrome 34','USERBROWSER_Chrome 46','USERBROWSER_Chrome 51',
 'USERBROWSER_Chrome 52','USERBROWSER_Chrome 56','USERBROWSER_Chrome 57',
 'USERBROWSER_Chrome 58','USERBROWSER_Chrome 59','USERBROWSER_Chrome 60',
 'USERBROWSER_Chrome 61','USERBROWSER_Firefox 45','USERBROWSER_Firefox 47',
 'USERBROWSER_Firefox 51','USERBROWSER_Firefox 52','USERBROWSER_Firefox 53',
 'USERBROWSER_Firefox 54','USERBROWSER_Firefox 55','USERBROWSER_Firefox 56',
 'USERBROWSER_IE 10.0','USERBROWSER_IE 11.0','USERBROWSER_IE 6.0',
 'USERBROWSER_IE 7.0','USERBROWSER_IE 8.0','USERBROWSER_IE 9.0',
 'USERBROWSER_Other','USERBROWSER_Safari 10','USERBROWSER_Safari 9',
 'USERBROWSER_wbxtpgw','DOWNLOADMETHOD_ActiveX','DOWNLOADMETHOD_Extension',
 'DOWNLOADMETHOD_GPC Plugin','DOWNLOADMETHOD_Java Applet Java Client',
 'DOWNLOADMETHOD_Java Applet Native Client','DOWNLOADMETHOD_TFS',
 'DOWNLOADMETHOD_Unknown','SERVICETYPE_EC','SERVICETYPE_MC',
 'SERVICETYPE_SC','SERVICETYPE_TC','SERVICETYPE_UNKNOWN',
 'MACHINE_TYPE_Moblie','MACHINE_TYPE_Other','MACHINE_TYPE_PC'],
                    class_names=['0','1','2'],  
                    filled=True, rounded=True,  
                    special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# 决策树分类准确率计算
jmt_predict_test = jmt_DTC.predict(jmt_sample_test)
print accuracy_score(jmt_target_test, jmt_predict_test)
# Out:
# 0.835677154301

# %%
confusion = confusion_matrix(jmt_target_test, jmt_predict_test)
print confusion
# 混淆矩阵C 如下定义，对于第i行，第j列的元素C(i,j)表示正确分类为 group_i 类，实际预测为 group_j类。
# 也就是说，列表示预测的类别。行表示实际类别。
# 详细可见：http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html#sklearn.metrics.confusion_matrix
# Out:
# [[ 44925  55735]
#  [  8181 280125]]

# %%
print '每个分类的准确率、召回率、f1-score'
print classification_report(jmt_target_test, jmt_predict_test, target_names=['0', '1', '2'])
# Out:
# 每个分类的准确率、召回率、f1-score
#              precision    recall  f1-score   support
#
#           0       0.85      0.45      0.58    100660
#           1       0.83      0.97      0.90    288306
#
# avg / total       0.84      0.84      0.82    388966
